# %%
import cProfile
from scripts import parse_log as pl
from scripts import plot_data as dplt
from scripts import learn_scatterplot as lsctrplt
import time
startTime = time.time()

pl.setLogPath("datasets/shen.log")
df2 = pl.getPauses()
concurr = pl.getConcurrentDurations(False)
print(concurr)
dplt.plot_scatter(df2)
# dplt.plot_pauses(df)

# dplt.plot_heatmap(df)

#print(df)
executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
#      TimeFromStart TypeLogLine   ConcurrentPhase         AdditionalNotes  \
# 0            0.064        info             reset                    None
# 1            0.065        info           marking                    None
# 2            0.066        info   weak references                    None
# 3            0.066        info        weak roots                    None
# 4            0.066        info           cleanup        16M->16M(15360M)
# ..             ...         ...               ...                     ...
# 99          21.454       info            cleanup  13667M->13659M(15360M)
# 100         21.471       info              reset                    None
# 101         21.594       info            marking                    None
# 102        477.289       info              reset                    None
# 103        477.291       info            marking                    None
#
#          MemoryChange PauseDuration  PauseType
# ...

# %%
# Overhead : For development only.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
