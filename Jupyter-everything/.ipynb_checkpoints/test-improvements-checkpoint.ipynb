# %%
from scripts import parse_log as pl
from scripts import plot_data as dplt
import matplotlib.pyplot as plt
import matplotlib
import random as r
def createXYdata():
    data = [(i, r.randint(0, 100)) for i in range(20)]
    x = [d[0] for d in data]
    y = [d[1] for d in data]
    return [x, y]
def plot_bar(x, y, ax, color, label):
    ax.bar(x, y, color = color, label = label)
    
fig, ax = plt.subplots()
x,y = createXYdata()
plot_bar(x, y, ax, "r", "red bars")
x,y = createXYdata()
plot_bar(x, y, ax, "k", "black bars")
x,y = createXYdata()
plot_bar(x, y, ax, "orange", "orange bars")



plt.legend()
plt.show()

# %%
from scripts import updated_plot_data as uplt
import matplotlib.pyplot as plt
import random as r
from scripts import updated_parse_data as upl
# Purpose: Compare any number of logs using the updated parsing/plotting

# setup the figure to collect the plots onto.
fix, axs = plt.subplots()

# Process the first log, and plot it
pauses_df,_ = upl.getPauses(logfile = "datasets/cl_2.log")
x, y = uplt.get_combined_xy_pauses(pauses_df)
uplt.plot_pauses_bar(x, y, axs, label = "Pauses in 2")

# Process a second log.
p2_df, _ = upl.getPauses(logfile = "datasets/cl_1.log")
x, y = uplt.get_combined_xy_pauses(p2_df)
uplt.plot_pauses_bar(x, y, axs, label = "Pauses in 1")

plt.show()
# Out:
#      TimeFromStart_seconds TypeLogLine       MemoryChange  \
# 0                    0.167       info      55M->9M(1040M)
# 1                    0.360       info    121M->13M(1040M)
# 2                    1.140       info    597M->71M(1040M)
# 3                    3.175       info    455M->83M(1040M)
# 4                    6.686       info    475M->94M(1248M)
# ..                     ...         ...                ...
# 349               1190.891       info   843M->132M(1248M)
# 350               1194.290       info   844M->132M(1248M)
# 351               1197.733       info   844M->131M(1248M)
# 352               1200.706       info   843M->132M(1248M)
# 353               1204.868       info   844M->122M(1248M)
#
#      PauseDuration_miliseconds  PauseType
# 0                        4.652          0
# 1                        4.099          0
# 2                       22.746          0
# 3                       59.952          0
# 4                       10.748          0
# ..                         ...        ...
# 349                      7.372          0
# 350                      7.008          0
# 351                      6.582          0
# 352                      7.173          0
# 353                      5.148          0
#
# [354 rows x 5 columns]
# (     TimeFromStart_seconds TypeLogLine       MemoryChange  \
# 0                    0.166       info      55M->9M(1040M)
# 1                    0.347       info    121M->12M(1040M)
# 2                    1.177       info    612M->71M(1040M)
# 3                    3.368       info    471M->88M(1040M)
# 4                    6.982       info    488M->95M(1248M)
# ..                     ...         ...                ...
# 349               1190.526       info   844M->131M(1248M)
# 350               1194.001       info   843M->132M(1248M)
# 351               1197.521       info   844M->131M(1248M)
# 352               1200.566       info   843M->132M(1248M)
# 353               1204.652       info   844M->123M(1248M)
#
#      PauseDuration_miliseconds  PauseType
# 0                        4.856          0
# 1                        3.440          0
# 2                       21.828          0
# 3                       60.926          0
# 4                       11.822          0
# ..                         ...        ...
# 349                      6.758          0
# 350                      7.384          0
# 351                      7.592          0
# 352                      7.245          0
# 353                      5.833          0
#
# [354 rows x 5 columns], [[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['0.166s', '0.347s', '1.177s', '3.368s', '6.982s', '10.300s', '12.446s', '15.086s', '18.514s', '21.930s', '25.250s', '28.613s', '32.093s', '35.487s', '38.907s', '42.367s', '45.795s', '49.224s', '52.637s', '56.054s', '59.502s', '62.956s', '66.401s', '69.912s', '73.373s', '76.851s', '80.290s', '83.795s', '87.257s', '90.745s', '94.205s', '97.692s', '101.138s', '104.633s', '108.060s', '111.490s', '114.916s', '118.407s', '121.887s', '125.438s', '128.902s', '132.421s', '135.827s', '139.313s', '142.704s', '146.116s', '149.626s', '153.121s', '156.589s', '160.057s', '163.526s', '166.950s', '170.449s', '173.898s', '177.349s', '180.853s', '184.333s', '187.821s', '191.305s', '194.807s', '198.303s', '201.819s', '205.322s', '208.787s', '212.341s', '215.815s', '219.280s', '222.700s', '226.188s', '229.710s', '233.186s', '236.629s', '240.075s', '243.538s', '247.010s', '250.513s', '253.957s', '257.302s', '260.764s', '264.220s', '267.602s', '271.094s', '274.476s', '277.959s', '281.390s', '284.885s', '288.321s', '291.773s', '295.250s', '298.757s', '302.169s', '305.618s', '309.040s', '312.506s', '315.917s', '319.349s', '322.770s', '326.232s', '329.688s', '333.146s', '336.609s', '340.073s', '343.573s', '347.021s', '350.466s', '353.883s', '357.325s', '360.783s', '364.235s', '367.695s', '371.151s', '374.633s', '378.063s', '381.483s', '384.872s', '388.320s', '391.740s', '395.220s', '398.617s', '402.093s', '405.542s', '408.942s', '412.342s', '415.816s', '419.208s', '422.611s', '426.106s', '429.505s', '432.969s', '436.440s', '439.900s', '443.390s', '446.789s', '450.290s', '453.721s', '457.216s', '460.645s', '464.065s', '467.438s', '470.825s', '474.233s', '477.697s', '481.057s', '484.523s', '487.952s', '491.426s', '494.845s', '498.284s', '501.758s', '505.179s', '508.598s', '512.013s', '515.464s', '518.871s', '522.334s', '525.735s', '529.178s', ' ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-8ae5aafb8db2> in <module>
#      15 # Process a second log.
#      16 p2_df = upl.getPauses(logfile = "datasets/cl_1.log")
# ---> 17 x, y = uplt.get_combined_xy_pauses(p2_df)
#      18 uplt.plot_pauses_bar(x, y, axs, label = "Pauses in 1")
#      19
#
# ~/Desktop/Project/Jupyter-everything/scripts/updated_plot_data.py in get_combined_xy_pauses(dataframe)
#      48 def get_combined_xy_pauses(dataframe):
#      49     print(dataframe)
# ---> 50     if dataframe.empty:
#      51         return []
#      52     else:
#
# AttributeError: 'tuple' object has no attribute 'empty'

# %%
# Overhead : For development only.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
