# %%
# Overhead : For development only.
# %load_ext autoreload
# %autoreload 2
def generateTable():
    table = [[], [], [], [], []]
    for i in range(200):
        p = 0
        while p < i:
            table[0].append(str(i) + "s")
            table[-1].append(i * 3)
            p += 1
    return table

table = generateTable()

from scripts import process_log as pl
from scripts import plot_data as dplt


dplt.plot_heatmap(table, 50, labels = False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# next
# Num buckets in x_b is... 50
