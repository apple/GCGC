# %%
import numpy as np
import matplotlib.pyplot as plt

threshold = 0.1
data = np.random.random((10,10))
for row in range(10):
    for col in range(10):
        data[row][col] = round(data[row][col], 2)

fig, ax = plt.subplots()
im = ax.imshow(data, cmap=plt.cm.hot, interpolation='none', vmin=threshold)
cbar = fig.colorbar(im, extend='min')
cbar.cmap.set_under('green')

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(10):
    for j in range(10):
        text = ax.text(j, i, data[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()
# Out:
# <ipython-input-17-0912bd64379f>:13: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("hot").copy()
#   cbar.cmap.set_under('green')
